# %% [markdown]
# <img src='https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQ-VfNtOyJbsaxu43Kztf_cv1mgBG6ZIQZEVw&usqp=CAU'>
#
# # Procesamiento de Lenguage Natural
#
# ## Taller #9: Visualizaciones para NLP
#
#
# `Modo de entrega: Subir link de GitHub al aula virtual.`
#
# ### Presentado por: Juan Sebastian Cruz Dionicio

# %%
import pandas as pd 

data = pd.read_csv('hween_clean.csv')
data.head()
# Out:
#                                                texto                fecha  \
# 0  ¿Desparchado porque mañana no podrás salir a p...  2020-10-31 00:16:27
# 1  Participa en nuestro concurso de disfraces y l...  2020-10-31 00:15:34
# 2  MEGA-ESPECIAL Halloween 🎃 (Parte 53). Yo veo u...  2020-10-31 00:13:59
# 3  Un mensaje especial para los padres de familia...  2020-10-31 00:11:46
# 4                        Luna azul con halloween 🤪👻🤔  2020-10-31 00:10:04
#
#    ciudad  departamento       lat        lon
# 0  Bogotá  Cundinamarca  4.649178 -74.062827
# 1  Bogotá  Cundinamarca  4.649178 -74.062827
# 2  Bogotá  Cundinamarca  4.649178 -74.062827
# 3  Bogotá  Cundinamarca  4.649178 -74.062827
# 4  Bogotá  Cundinamarca  4.649178 -74.062827

# %%
import numpy as np

 

from wordcloud import WordCloud
from wordcloud import ImageColorGenerator

 

from nltk.corpus import stopwords
stopwords = stopwords.words('spanish')

 

import matplotlib.pyplot as plt
import PIL.Image
from IPython.display import display

# %%
arbol = PIL.Image.open("navidad.png")
display(arbol)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=860x919 at 0x16B5DBBDF48>

# %%
mask = np.array(arbol)
mask
# Out:
# array([[[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        ...,
#
#        [[238, 238, 238, 255],
#         [238, 238, 238, 255],
#         [238, 238, 238, 255],
#         ...,
#         [238, 238, 238, 255],
#         [238, 238, 238, 255],
#         [238, 238, 238, 255]],
#
#        [[238, 238, 238, 255],
#         [238, 238, 238, 255],
#         [238, 238, 238, 255],
#         ...,
#         [238, 238, 238, 255],
#         [238, 238, 238, 255],
#         [238, 238, 238, 255]],
#
#        [[238, 238, 238, 255],
#         [238, 238, 238, 255],
#         [238, 238, 238, 255],
#         ...,
#         [238, 238, 238, 255],
#         [238, 238, 238, 255],
#         [238, 238, 238, 255]]], dtype=uint8)

# %%
palabras = data.texto.str.cat(sep=' ')

 

wordcloud = WordCloud(width=800, height=400,
                     max_font_size=150, max_words=250,
                     background_color='white', colormap='copper_r',
                     stopwords=stopwords,
                     mask=mask, contour_width=0.5, contour_color='orange').generate(palabras) # https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html

 

wordcloud.to_file("arbol.png")

 

plt.figure(figsize=(10,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()
